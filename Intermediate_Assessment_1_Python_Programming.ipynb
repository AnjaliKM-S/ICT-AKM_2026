# %% [markdown]
# <a href="https://colab.research.google.com/github/AnjaliKM-S/ICT-AKM_2026/blob/main/Intermediate_Assessment_1_Python_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Challenge 1: Word Frequency Analyzer
# Write a function `top_k_words(filename: str, k: int) -> list` that returns the top k frequent words.
# - Ignore case and punctuation.
# - Sort by frequency, then alphabetically.

# %%
import re
from collections import Counter

def top_k_words(filename: str, k: int) -> list:
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read().lower()

    # ignore punctuation
    words = re.findall(r'\b\w+\b', text)

    # Count frequencies
    counts = Counter(words)

    # Sort by frequency (desc), then alphabetically (asc)
    sorted_words = sorted(counts.items(), key=lambda x: (-x[1], x[0]))

    # Return only top k words
    return [word for word, freq in sorted_words[:k]]


# Sample Test
with open("sample.txt", "w") as f:
    f.write("Data science is evolving. Python is versatile. Learning never stops.")

print(top_k_words("sample.txt", 3))
# Out:
# ['is', 'data', 'evolving']

# %%
with open("sample.txt", "w") as f:
    f.write("Data science is evolving. Python is versatile. Learning never stops.")

print(top_k_words("sample.txt", 5))
# Out:
# ['is', 'data', 'evolving', 'learning', 'never']

# %% [markdown]
# ## Challenge 2 : Analyze daily expenses and extract insights.
# User enters:
#
# Number of transactions
# Category and amount
#
# Food 200
# Travel 500
# Food 300
# Shopping 700
#
# ### Output
# * Total expense
# * Highest expense category
# * Category-wise total

# %%
def analyze_expenses():
    n = int(input("Enter number of transactions: "))

    expenses = {}

    for _ in range(n):
        category, amount = input().split()
        amount = float(amount)

        if category in expenses:
            expenses[category] += amount
        else:
            expenses[category] = amount

    # calculate total expense
    total = sum(expenses.values())

    # find highest category
    highest_category = max(expenses, key=expenses.get)

    print("Total Expense:", total)
    print("Highest Category:", highest_category)
    print("Category-wise:", expenses)

analyze_expenses()
# Out:
# Enter number of transactions: 4
# Food 200
# Travel 500
# Food 300
#  Shopping 700
# Total Expense: 1700.0
# Highest Category: Shopping
# Category-wise: {'Food': 500.0, 'Travel': 500.0, 'Shopping': 700.0}

# %% [markdown]
# ### Challenge 3: Data Cleaner (Mini Pandas Logic Without Pandas)
#
# 10 ,20 ,abc ,30 ,-5 , 40
#
# * Remove invalid values
# * Remove negative values
#
#
# Show:
# * Clean list
# * Average
# * Max value

# %%
def clean_data():
    n = int(input("Enter number of values: "))

    data = []

    for _ in range(n):
        value = input()

        try:
            num = float(value)

            # to ignore negative values
            if num >= 0:
                data.append(num)

        except:

            continue

    # calculate average
    avg = sum(data) / len(data) if data else 0

    # find max
    max_val = max(data) if data else None

    print("Clean Data:", data)
    print("Average:", avg)
    print("Max:", max_val)

clean_data()
# Out:
# Enter number of values: 6
# 10
# 20
# abc
# 30
# -5
# 40
# Clean Data: [10.0, 20.0, 30.0, 40.0]
# Average: 25.0
# Max: 40.0
