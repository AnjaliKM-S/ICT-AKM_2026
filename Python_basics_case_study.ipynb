# %% [markdown]
# <a href="https://colab.research.google.com/github/AnjaliKM-S/ICT-AKM_2026/blob/main/Python_basics_case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##1.Bank Account Manager

# %%
##Simulate a bank account with deposit, withdrawal, and balance enquiry operations
Account_holder1 = 20000
Account_holder2 = 13000.55
Account_holder3 = 550.56

Balance_holder1 = 20000
Balance_holder2 = 13000.55
Balance_holder3 = 550.56

print(Account_holder1)
print(Balance_holder3)
# Out:
# 20000
# 550.56

# %%
##Use variables and data types to store account information
Account_holder3 = Current_balance_holder3
print(Account_holder3)
print("Account_holder3")
print(type(Balance_holder1))
print (type(Balance_holder2))
# Out:
# 550.56
# Account_holder3
# <class 'int'>
# <class 'float'>

# %%
#Implement conditional statements to check for sufficient balance before withdrawal

Balance_holder1 = 20000
Withdrawal_amount = int(input("Enter the amount:"))
if(Withdrawal_amount>20000) :
   print( "Sufficient balance")
else :
  print("Insufficient balance")


  Balance_holder3 = 20000
Withdrawal_amount = int(input("Enter the amount:"))
if(Withdrawal_amount>20000) :
   print( "Sufficient balance")
else :
  print("Insufficient balance")
# Out:
# Enter the amount:20000
# Insufficient balance
# Enter the amount:1000
# Insufficient balance

# %%
# Account balances
Balance_holder1 = 20000
Balance_holder2 = 13000.55
Balance_holder3 = 550.56

# Deposit
def deposit(balance, amount):
    balance = balance + amount
    return balance
    Balance_holder1 = deposit(Balance_holder1, 5000)
    check_balance(Balance_holder1)


# Withdraw
def withdraw(balance, amount):
    if amount <= balance:
        balance = balance - amount
    else:
        print("Insufficient balance")
    return balance
    Balance_holder2 = withdraw(Balance_holder2, 2000)
    check_balance(Balance_holder2)

# Balance enquiry
def check_balance(balance):
    print("Current Balance:", balance)
check_balance(Balance_holder3)
# Out:
# Current Balance: 25000
# Current Balance: 11000.55
# Current Balance: 550.56

# %% [markdown]
# ##2.Weather Data Analyzer

# %%
#a. Analyze weather data (temperature, humidity, etc.) for a given region
# weather data
temperature =[30,32,31]
humidity =[70,72,73]
print(temperature)
print(humidity)
avg_temp = sum(temperature)/len(temperature)
avg_hum = sum(humidity) /len(humidity)

print(avg_temp)
print(avg_hum)
# Out:
# [30, 32, 31]
# [70, 72, 73]
# 31.0
# 71.66666666666667

# %%
#b. Use variables and data types to store weather data

city = 'kasaragod'
temperature = [30,32,31]
humidity =[70,72,73]
current_temperature = 24.5
print("city is",city)
print("temperature:", temperature,"°C")
print ("humidity :", humdity, "%")

print(type(temperature))
print(type(current_temperature))
# Out:
# city is kasaragod
# temperature: [30, 32, 31] °C
# humidity : [70, 72, 73] %
# <class 'list'>
# <class 'float'>

# %%
# Implement conditional statements to determine weather conditions(sunny, rainy, etc.)

if (current_temperature >24) :
   print( "Raining")
else :
  print("Sunny")

temperature = int(input("Enter the temperature:"))
if (temperature > 24) :
   print( "its sunny day")

elif (temperature==24): print("Cloudy day")
elif (temperature< 24): print("Rainy day")
else :
  print("raining")
# Out:
# Raining
# Enter the temperature: 32
# its sunny day

# %%
temperature = int(input("Enter the temperature:"))
if (temperature > 24) :
   print( "its sunny day")

elif (temperature==24): print("Cloudy day")
elif (temperature< 24): print("Rainy day")
else :
  print("raining")
# Out:
# Enter the temperature:24
# Cloudy day

# %%
#Use functions to calculate average temperature and humidity, and print results

def calculate_average(temperature) :
  return sum(temperature)/len(temperature)

  avg_temp = calculate_average(temperature)
  avg_hum = calculate_average(humidity)

print('Average temperature:', avg_temp)
print("Average humidity:", avg_hum)
# Out:
# Average temperature: 31.0
# Average humidity: 71.66666666666667
